# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
reviews = pd.read_csv("winemag-data_first150k.csv", index_col=0)

# %%
reviews.columns
# Out:
# Index(['country', 'description', 'designation', 'points', 'price', 'province',
#        'region_1', 'region_2', 'variety', 'winery'],
#       dtype='object')

# %%
reviews._get_numeric_data().columns
# Out:
# Index(['points', 'price'], dtype='object')

# %%
reviews['province'].value_counts().head(8).plot.bar()

# %%
(reviews['province'].value_counts().head(8)/reviews.shape[0]*100).plot.bar()

# %%
reviews['points'].value_counts().sort_index().plot.bar()

# %%
len(reviews['points'].unique())
# Out:
# 21

# %%
reviews['points'].value_counts().sort_index().plot.line()

# %%
reviews['points'].value_counts().sort_index().plot.area()

# %%
reviews['price'].value_counts().sort_index().head(500).plot.line()

# %%
reviews[reviews['price'] < 200]['price'].value_counts().sort_index().head(500).plot.line()

# %%
reviews[reviews['price'] < 200]['price'].plot.hist()

# %%
reviews[reviews['price'] > 1200]
# Out:
#       country                                        description  \
# 13318      US  The nose on this single-vineyard wine from a s...
# 26296  France  A wine that has created its own universe. It h...
# 34920  France  A big, powerful wine that sums up the richness...
# 34922  France  A massive wine for Margaux, packed with tannin...
# 34939  France  The purest Cabernet Sauvignon fruit, with dark...
# 51886  France  A wine that has created its own universe. It h...
# 83536  France  A wine that has created its own universe. It h...
#
#                designation  points   price    province     region_1  \
# 13318  Roger Rose Vineyard      91  2013.0  California  Arroyo Seco
# 26296       Clos du Mesnil     100  1400.0   Champagne    Champagne
# 34920                  NaN      99  2300.0    Bordeaux     Pauillac
# 34922                  NaN      98  1900.0    Bordeaux      Margaux
# 34939                  NaN      96  1300.0    Bordeaux     Pauillac
# ...

# %%
reviews['points'].plot.hist()

# %%
reviews.head()
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# ...

# %%
reviews[reviews['points'] > 90].plot.scatter(x='price',y='points')

# %%
reviews[(reviews['points'] > 60) & (reviews['points'] < 90)].plot.scatter(x='price',y='points')

# %%
"""Because of their weakness to overplotting, scatter plots work 
best with relatively small datasets, 
and with variables which have a large number of unique values"""
# Out:
# 'Because of their weakness to overplotting, scatter plots work \nbest with relatively small datasets, \nand with variables which have a large number of unique values'

# %%
reviews.plot.hexbin(x='price', y='points', gridsize=15)

# %%
reviews['points'].value_counts().sort_index().plot.bar()

# %%
sns.countplot(reviews['points'])

# %%
sns.kdeplot(reviews.query('price < 200').price)
